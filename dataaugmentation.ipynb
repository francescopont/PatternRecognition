# %%
import Augmentor

pipeline = Augmentor.Pipeline("Test_Images")
# Out:
# Initialised with 1 image(s) found.
# Output directory set to Test_Images\output.

# %%
pipeline.random_distortion( probability =1, grid_width =4, grid_height =4, magnitude =5)
pipeline.rotate ( probability =0.5 , max_left_rotation =10 , max_right_rotation =10)
pipeline.sample(10)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=489x483 at 0x16EA3BD9F60>: 100%|█| 10/10 [00:01<00:00,  5.51 Samples/s]

# %%
import glob
from IPython.display import Image, display
for imageName in glob.glob('Test_Images/output/*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print(imageName)
# Out:
# Test_Images/output\Test_Images_original_fig_4.jpg_2ae85ad1-42b9-4148-98df-78aa1961cdcb.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_2b996cc1-32a0-4d23-9655-ede362403f60.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_3df7d016-1df7-41b6-ba11-2b6da30cf8d4.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_72ac556e-ec3e-4a2c-86b5-6122432b130f.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_8043f9fd-8bd8-46cf-a44d-6772c66f90bd.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_8e934155-9fbe-4eb9-be14-b092fba0c9ef.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_bf2861ce-584e-4fce-8632-5837d6aba202.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_d55f3a5b-9394-458c-bdeb-6481266b878c.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_e728f224-a0d7-4a82-a98f-80c62e8f55bf.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_f4cce8b8-942b-4442-9a47-4cdea825f5b8.jpg
