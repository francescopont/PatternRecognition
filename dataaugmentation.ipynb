# %%
import Augmentor

pipeline = Augmentor.Pipeline("")
# Out:
# Initialised with 1 image(s) found.
# Output directory set to Test_Images\output.

# %%
pipeline.random_distortion( probability =1, grid_width =1, grid_height =1, magnitude =20)
pipeline.sample(1)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=489x483 at 0x272CFA0EF98>: 100%|███| 1/1 [00:00<00:00,  5.39 Samples/s]

# %%
import glob
from IPython.display import Image, display
for imageName in glob.glob('Test_Images/output/*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print(imageName)
# Out:
# Test_Images/output\Test_Images_original_fig_4.jpg_189ecef0-c7a0-47a5-a743-dfe8b115bb03.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_8399c09a-8d5f-4fdb-9ab4-ca0851cf333c.jpg
