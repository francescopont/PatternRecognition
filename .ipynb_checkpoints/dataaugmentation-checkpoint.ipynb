# %%
import Augmentor

pipeline = Augmentor.Pipeline("Test_Images")
# Out:
# Initialised with 1 image(s) found.
# Output directory set to Test_Images\output.

# %%
pipeline.random_distortion( probability =1, grid_width =4, grid_height =4, magnitude =5)
pipeline.sample(10)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=489x483 at 0x272CFA07080>: 100%|█| 10/10 [00:00<00:00, 45.58 Samples/s]

# %%
import glob
from IPython.display import Image, display
for imageName in glob.glob('Test_Images/output/*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print(imageName)
# Out:
# Test_Images/output\Test_Images_original_fig_4.jpg_006ce935-881e-48c1-95d8-db7712e0b8bd.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_4512d26e-5b48-40c8-badd-502ac8eefa80.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_6a20f76b-c7d6-42bb-8ec9-ed40130a1383.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_77be6130-9aed-46eb-b422-732a65a4a05b.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_83be9a18-475c-471d-930d-b1e5c4455a77.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_85f062aa-6236-474a-9687-3f83f633342d.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_bbb8c05d-a170-4e59-a1ee-d7ecf2af990c.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_c95869d0-c440-43af-a872-b9d1c41bef45.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_d3313078-df0d-4aa6-bbbb-3418e72d3142.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_e45bb3e3-3453-4b97-9e79-15349641e9b1.jpg
