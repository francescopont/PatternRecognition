# %%
import Augmentor

pipeline = Augmentor.Pipeline("Test_Images")
# Out:
# Initialised with 1 image(s) found.
# Output directory set to Test_Images\output.

# %%
pipeline.random_distortion( probability =1, grid_width =4, grid_height =4, magnitude =5)
pipeline.rotate ( probability =0.5 , max_left_rotation =10 , max_right_rotation =10)
pipeline.sample(10)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=489x483 at 0x16EA3BD9240>: 100%|█| 10/10 [00:00<00:00, 15.93 Samples/s]

# %%
import glob
from IPython.display import Image, display
for imageName in glob.glob('Test_Images/output/*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print(imageName)
# Out:
# Test_Images/output\Test_Images_original_fig_4.jpg_10addcdd-c31f-45e2-bdf4-995ca83ecad4.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_177bb196-f549-4a64-816e-cb21f44b10a5.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_3e3d60ad-4a95-49dd-b19d-9025a0aa8de6.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_400ad5dc-9682-4d66-b5e1-19db4386c54c.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_5033b0af-e583-4989-8c41-f33b18339d5a.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_5e2fafef-849c-489d-bbe7-c11ecf84d326.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_6c4518f8-045f-45c5-a81a-6110a22e2c73.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_80820c14-802b-4471-b4bc-d8a255a8a1b0.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_852f8a95-82a7-4eaa-b16b-9e5ef97e3686.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_906ce794-d3a2-4053-a3ec-c376d27efdd6.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_a0490e5a-942f-4490-9f59-6042b4a9928d.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_af891863-619e-41af-9259-87cec0cfa155.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_b0da7fec-38fc-4b53-92ac-78e27800ff8e.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_c6a62776-783a-453f-aafe-2c2ba020cb9f.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_ca5c9751-7c44-4f8c-afc3-cb020556c517.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_d0527bce-cd84-4313-a403-375ded7a5b72.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_da8ae757-2420-4cf2-a09e-9ceae30a1b5b.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_e06d0acf-802d-44cb-9600-f14ad9ebdcb7.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_ebbc6721-6510-4aea-9d6b-abc85408ff94.jpg
# Test_Images/output\Test_Images_original_fig_4.jpg_f607e98e-4835-49f1-bafa-3fad23d9c880.jpg
